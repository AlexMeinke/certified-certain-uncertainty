# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import matplotlib.pyplot as plt

from importlib import reload

import models
import plotting
import dataloaders as dl
import traintest as tt

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
base_model = torch.load('SavedModels/base_model.pth').to(device)
gmm_model = torch.load('SavedModels/gmm_model.pth').to(device)
qmm_model = torch.load('SavedModels/qmm_model.pth').to(device)

# %%
#robust_model.log_pz_lam.data = torch.tensor(-5.).to(device)

data = enumerate(dl.test_loader).__next__()[1][0]
y = gmm_model(data.to(device))
y_base = base_model(data.to(device))

plotting.plot_samples([y_base, y], data)
    
data = enumerate(dl.EMNIST_test_loader).__next__()[1][0]
y = gmm_model(data.to(device))
y_base = base_model(data.to(device))

plotting.plot_samples([y_base, y], data)

# %%
gmm_model.eval()
perturbed_image = tt.generate_adv_noise(base_model, .9, device=device)

y = gmm_model(perturbed_image.to(device))
y_base = base_model(perturbed_image.to(device))

plotting.plot_samples([y_base, y], perturbed_image.detach().cpu())

# %%
import torch

lr = .0001
momentum = .9

#optimizer = optim.SGD([{"params":robust_model.gmm.parameters()}, {"params":robust_model.log_pz_lam}], lr=lr, momentum=momentum)

#optimizer = optim.SGD(robust_model.gmm.parameters(), lr=lr, momentum=momentum)
optimizer = optim.SGD([gmm_model.mm.alpha, robust_model.mm.logvar], lr=lr, momentum=momentum)


for epoch in range(2):
    optimizer.param_groups[0]['lr'] *= .8
    tt.train_adv(gmm_model, device, dl.train_loader, optimizer, epoch)
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 0.774529
# Train Epoch: 0 [10000/60000 (17%)]	Loss: 1.372429
# Train Epoch: 0 [20000/60000 (33%)]	Loss: 1.351294
# Train Epoch: 0 [30000/60000 (50%)]	Loss: 1.374229
# Train Epoch: 0 [40000/60000 (67%)]	Loss: 1.330523
# Train Epoch: 0 [50000/60000 (83%)]	Loss: 1.340730
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.340102
# Train Epoch: 1 [10000/60000 (17%)]	Loss: 1.323793
# Train Epoch: 1 [20000/60000 (33%)]	Loss: 1.295429
# Train Epoch: 1 [30000/60000 (50%)]	Loss: 1.326414
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 1.320783
# Train Epoch: 1 [50000/60000 (83%)]	Loss: 1.303746

# %%
robust_model.eval()

perturbed_image = tt.generate_adv_noise(gmm_model.base_model, 3., device=device)

y = gmm_model(perturbed_image.to(device))
y_base = base_model(perturbed_image.to(device))

plotting.plot_samples([y_base, y], perturbed_image.cpu())


data = enumerate(dl.test_loader).__next__()[1][0]
y = gmm_model(data.to(device))
y2 = gmm_model.base_model(data.to(device))
y_base = base_model(data.to(device))

plotting.plot_samples([y_base, y2, y], data)


data = enumerate(dl.EMNIST_test_loader).__next__()[1][0]
y = gmm_model(data.to(device))
y2 = gmm_model.base_model(data.to(device))
y_base = base_model(data.to(device))

plotting.plot_samples([y_base, y2, y], data)

# %%
tt.test(gmm_model, device, dl.test_loader)
tt.test(qmm_model, device, dl.test_loader)
tt.test(base_model, device, dl.test_loader)
# Out:
# Test set: Average loss: 0.2151, Accuracy: 9898/10000 (99%), Ave. Confidence: 83%
#
#
# Test set: Average loss: 0.0409, Accuracy: 9898/10000 (99%), Ave. Confidence: 97%
#
#
# Test set: Average loss: 0.0349, Accuracy: 9898/10000 (99%), Ave. Confidence: 98%
# (9898, 0.9807402558326721)

# %%
tt.test_adv(gmm_model, device, dl.EMNIST_test_loader)
tt.test_adv(qmm_model, device, dl.EMNIST_test_loader)
tt.test_adv(base_model, device, dl.EMNIST_test_loader)
# Out:
# Ave. Confidence: 50% Predicted: 100%
#
#
# Ave. Confidence: 79% Predicted: 100%
#
#
# Ave. Confidence: 79% Predicted: 100%
# 0.7899127984505433

# %%
like = gmm_model.mm(dl.X_MNIST[0:300].to(device))
like_E = gmm_model.mm(dl.X_EMNIST[0:300].to(device))
plt.hist(torch.logsumexp(like,dim=0).detach().cpu(), density=True, alpha=.6)
plt.hist(torch.logsumexp(like_E,dim=0).detach().cpu(), density=True, alpha=.6)
plt.show()

like2 = qmm_model.mm(dl.X_MNIST[0:300].to(device))
like_E2 = qmm_model.qmm(dl.X_EMNIST[0:300].to(device))
plt.hist(torch.logsumexp(like2,dim=0).detach().cpu(), density=True, alpha=.6)
plt.hist(torch.logsumexp(like_E2,dim=0).detach().cpu(), density=True, alpha=.6)
plt.show()

# %%
gmm_model.loglam.data = torch.tensor(-8.,device=device)
plt.figure(figsize=(15,4))


def bound(L):
    xi = (gmm_model.mm.calculate_bound(L)-gmm_model.loglam).exp()
    return .1*(1+10*xi)/(1+xi)

n = 1
data = []
for _ in range(n):
    data.append(enumerate(dl.train_loader).__next__()[1][0])
data_MNIST = torch.cat(data, dim=0)
Lm = (data_MNIST.view(n*100,784)[:,None,:]-dl.X_MNIST[None,:,:]).norm(dim=2).min(dim=1)[0]

data = []
for _ in range(n):
    data.append(enumerate(dl.EMNIST_train_loader).__next__()[1][0])
data_EMNIST = torch.cat(data, dim=0)
Le = (data_EMNIST.view(n*100,784)[:,None,:]-dl.X_MNIST[None,:,:]).norm(dim=2).min(dim=1)[0]

data = []
for _ in range(n):
    data.append(enumerate(dl.fashion_train_loader).__next__()[1][0])
data_FMNIST = torch.cat(data, dim=0)
Lf = (data_FMNIST.view(n*100,784)[:,None,:]-dl.X_MNIST[None,:,:]).norm(dim=2).min(dim=1)[0]


for i in range(3):
    plt.subplot(1,3,i+1)
    gmm_model.loglam.data += 2.
    xv = np.linspace(3., 16.,15)
    plt.plot(xv, [bound(x) for x in xv] )

    y = gmm_model(data_MNIST.to(device)).max(dim=1)[0].exp()
    ms = plt.scatter(Lm.detach(),y.detach().cpu().numpy(),alpha=.5)

    y = gmm_model(data_EMNIST.to(device)).max(dim=1)[0].exp()
    es = plt.scatter(Le.detach(),y.detach().cpu().numpy(),alpha=.5)
    
    y = gmm_model(data_FMNIST.to(device)).max(dim=1)[0].exp()
    fs = plt.scatter(Lf.detach(),y.detach().cpu().numpy(),alpha=.5)

    plt.xlabel('L=min_k d(mu_k,x)')
    plt.ylabel('max_c p(y=c|x)')
    plt.legend(( ms, es, fs),
               ('MNIST', 'EMNIST', 'FMNIST'))
    plt.ylim([0,1.02])
plt.show()

gmm_model.loglam.data = torch.tensor(-8.,device=device)
plt.figure(figsize=(15,4))

for i in range(3):
    plt.subplot(1,3,i+1)
    gmm_model.loglam.data += 2.
    xv = np.linspace(3., 16.,15)
    plt.plot(xv, [bound(x) for x in xv] )

    y = gmm_model.base_model(data_MNIST.to(device)).max(dim=1)[0].exp()
    ms = plt.scatter(Lm.detach(),y.detach().cpu().numpy(),alpha=.5)

    y = gmm_model.base_model(data_EMNIST.to(device)).max(dim=1)[0].exp()
    es = plt.scatter(Le.detach(),y.detach().cpu().numpy(),alpha=.5)
    
    y = gmm_model.base_model(data_FMNIST.to(device)).max(dim=1)[0].exp()
    fs = plt.scatter(Lf.detach(),y.detach().cpu().numpy(),alpha=.5)

    plt.xlabel('L=min_k d(mu_k,x)')
    plt.ylabel('max_c p(y=c|x)')
    plt.legend(( ms, es, fs),
               ('MNIST', 'EMNIST', 'FMNIST'))
    plt.ylim([0,1.02])
plt.show()

# %%
gmm_model.loglam.data = torch.tensor(-8.,device=device)



def bound(L, model):
    xi = (model.mm.calculate_bound(L)-model.loglam).exp()
    return .1*(1+10*xi)/(1+xi)

def visualize_bound(model, lamv, xv=np.linspace(0., 20.,15)):
    with torch.no_grad():
        temp_lam = model.loglam.data
        n = 1
        data = []
        for _ in range(n):
            data.append(enumerate(dl.train_loader).__next__()[1][0])
        data_MNIST = torch.cat(data, dim=0)
        Lm = (data_MNIST.view(n*100,784)[:,None,:]-dl.X_MNIST[None,:,:]).norm(dim=2).min(dim=1)[0]

        data = []
        for _ in range(n):
            data.append(enumerate(dl.EMNIST_train_loader).__next__()[1][0])
        data_EMNIST = torch.cat(data, dim=0)
        Le = (data_EMNIST.view(n*100,784)[:,None,:]-dl.X_MNIST[None,:,:]).norm(dim=2).min(dim=1)[0]

        data = []
        for _ in range(n):
            data.append(enumerate(dl.fashion_train_loader).__next__()[1][0])
        data_FMNIST = torch.cat(data, dim=0)
        Lf = (data_FMNIST.view(n*100,784)[:,None,:]-dl.X_MNIST[None,:,:]).norm(dim=2).min(dim=1)[0]

        plt.figure(figsize=(15,4))


        for i, lam in enumerate(lamv):
            plt.subplot(1,len(lamv),i+1)
            model.loglam.data = torch.tensor(lam, device=device)
            plt.plot(xv, [bound(x, model) for x in xv] )

            y = model(data_MNIST.to(device)).max(dim=1)[0].exp()
            ms = plt.scatter(Lm.detach(),y.detach().cpu().numpy(),alpha=.5)

            y = model(data_EMNIST.to(device)).max(dim=1)[0].exp()
            es = plt.scatter(Le.detach(),y.detach().cpu().numpy(),alpha=.5)

            y = model(data_FMNIST.to(device)).max(dim=1)[0].exp()
            fs = plt.scatter(Lf.detach(),y.detach().cpu().numpy(),alpha=.5)

            plt.xlabel('L=min_k d(mu_k,x)')
            plt.ylabel('max_c p(y=c|x)')
            plt.legend(( ms, es, fs),
                       ('MNIST', 'EMNIST', 'FMNIST'))
            plt.ylim([0,1.02])
        plt.show()
        model.loglam.data = temp_lam

# %%
visualize_bound(gmm_model, [-8.,-6.,-4.])

# %%
visualize_bound(qmm_model, [-8.,-6.,-4.])

# %%
bound(10, qmm_model)
# Out:
# tensor([0.8859, 0.8640, 0.7846, 0.8519, 0.8731, 0.8469, 0.8298, 0.7914, 0.8595,
#         0.8392, 0.8157, 0.7932, 0.8874, 0.8480, 0.8536, 0.8256, 0.8805, 0.8054,
#         0.8593, 0.7921, 0.7935, 0.8138, 0.8531, 0.8351, 0.8418, 0.8949, 0.8458,
#         0.8943, 0.8438, 0.8964, 0.8111, 0.8999, 0.8380, 0.8232, 0.8373, 0.8773,
#         0.8909, 0.8588, 0.8923, 0.8550, 0.8607, 0.8480, 0.8381, 0.8651, 0.8373,
#         0.8035, 0.7908, 0.8155, 0.8843, 0.8976, 0.8037, 0.8332, 0.8785, 0.8924,
#         0.8328, 0.8342, 0.8625, 0.7751, 0.8186, 0.8351, 0.8486, 0.8862, 0.8115,
#         0.8131, 0.8598, 0.8643, 0.8534, 0.8539, 0.8778, 0.8587, 0.8848, 0.7913,
#         0.8943, 0.8462, 0.8816, 0.8968, 0.8591, 0.8908, 0.7986, 0.7814, 0.7853,
#         0.8807, 0.9008, 0.8700, 0.8513, 0.7809, 0.8046, 0.8991, 0.8239, 0.8048,
#         0.7782, 0.8391, 0.8842, 0.7782, 0.8380, 0.7866, 0.8124, 0.8130, 0.8724,
#         0.8002, 0.8763, 0.8549, 0.8722, 0.8203, 0.8696, 0.7957, 0.7913, 0.8240,
#         0.8701, 0.7814, 0.8636, 0.8954, 0.8029, 0.7762, 0.8113, 0.8874, 0.8611,
#         0.8950, 0.8881, 0.8463, 0.8848, 0.8459, 0.8089, 0.7937, 0.7833, 0.8823,
#         0.7753, 0.8388, 0.8221, 0.8106, 0.7770, 0.8101, 0.8883, 0.8748, 0.8336,
#         0.8723, 0.8208, 0.7918, 0.7814, 0.8787, 0.8874, 0.8333, 0.8951, 0.8524,
#         0.8842, 0.8332, 0.8965, 0.8032, 0.8457, 0.7979, 0.8422, 0.8520, 0.8968,
#         0.8760, 0.8313, 0.8676, 0.8074, 0.8949, 0.8884, 0.8831, 0.8826, 0.8653,
#         0.8836, 0.8585, 0.8143, 0.7743, 0.8842, 0.8721, 0.7780, 0.8526, 0.8702,
#         0.8914, 0.7792, 0.8521, 0.8960, 0.7970, 0.8796, 0.7790, 0.8641, 0.8990,
#         0.8044, 0.8746, 0.8167, 0.7815, 0.8739, 0.8640, 0.7777, 0.8513, 0.8951,
#         0.8882, 0.8506, 0.7970, 0.8859, 0.8958, 0.8368, 0.8982, 0.8776, 0.7765,
#         0.8549, 0.8740, 0.8699, 0.8728, 0.8655, 0.8856, 0.8397, 0.8652, 0.8985,
#         0.8828, 0.8946, 0.8659, 0.8431, 0.8382, 0.8978, 0.8738, 0.8648, 0.7770,
#         0.8799, 0.8455, 0.7802, 0.8861, 0.8475, 0.7878, 0.8818, 0.8438, 0.8424,
#         0.8797, 0.8227, 0.8391, 0.7880, 0.8698, 0.8315, 0.8746, 0.8609, 0.8138,
#         0.9005, 0.7967, 0.8707, 0.8994, 0.8319, 0.8172, 0.8797, 0.8542, 0.8664,
#         0.8748, 0.8089, 0.8592, 0.7968, 0.7838, 0.8574, 0.7858, 0.8584, 0.8453,
#         0.8886, 0.8150, 0.8660, 0.8573, 0.8853, 0.8257, 0.8018, 0.8950, 0.8400,
#         0.8884], device='cuda:0', grad_fn=<DivBackward0>)

# %%
reload(models)
# Out:
# <module 'models' from '/home/alexm/project/notebooks/gmm-robust/models.py'>

# %%
bound(1., qmm_model)
# Out:
# tensor(0.9874, device='cuda:0', grad_fn=<DivBackward0>)

# %%
bound(0., qmm_model)
# Out:
# tensor(0.9874, device='cuda:0', grad_fn=<DivBackward0>)

# %%
torch.logsumexp(a, 0).exp()
# Out:
# tensor(0.0639, device='cuda:0', grad_fn=<ExpBackward>)
