# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
from sklearn.metrics import roc_auc_score
from sklearn import mixture, preprocessing, datasets

from importlib import reload
import matplotlib.pyplot as plt
from matplotlib import patches

import utils.models as models
import utils.plotting as plotting
import utils.dataloaders as dl
import utils.traintest as tt
import utils.adversarial as adv
import utils.eval as ev
import model_params as params
import utils.resnet_orig as resnet
import utils.gmm_helpers as gmm_helpers

from tensorboardX import SummaryWriter
# %load_ext line_profiler
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
class TwoMoonsNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(2, 32)
        self.fc2 = nn.Linear(32, 64)
        self.fc3 = nn.Linear(64, 2)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return F.log_softmax(x, dim=1)
    

def train(data, label, model, optimizer):
    criterion = nn.NLLLoss()
    
    y = model(data)
    optimizer.zero_grad()
    loss = criterion(y, label)
    loss.backward()
    optimizer.step()


def train_CEDA(data, label, model, optimizer):
    lam = 1.
    p_in = 1. / (1. + lam)
    p_out = lam * p_in
    
    log_p_in = torch.tensor(p_in, device=device).log()
    log_p_out = torch.tensor(p_out, device=device).log()
    
    criterion = nn.NLLLoss()
    
    noise = torch.rand_like(data)
    
    y = model(data)
    y_out = model(noise)
    optimizer.zero_grad()
    loss1 = criterion(y, label)
    loss2 = - y_out.mean()
    loss3 = - torch.logsumexp(torch.stack([log_p_in + like_in, 
                                           log_p_out*torch.ones_like(like_in)], 0), 0).mean()
    loss4 = - torch.logsumexp(torch.stack([log_p_in + like_out, 
                                           log_p_out*torch.ones_like(like_out)], 0), 0).mean()
    
    loss =  p_in*(loss1 + loss3) + p_out*(loss2 + loss4)
    
    loss.backward()
    optimizer.step()

# %%
moons_data, moons_label = datasets.make_moons(n_samples=500, shuffle=True, noise=.05)

data = torch.tensor(moons_data, dtype=torch.float)
label = torch.tensor(moons_label, dtype=torch.float)
label = label.type(torch.LongTensor)

net = TwoMoonsNet()

# %%
optimizer = optim.SGD(net.parameters(), lr=0.1)
for _ in range(1000):
    train(data, label, net, optimizer)

# %%
y = net(data).max(1)[1]
( y == label ).float().mean()

colors = np.array(['#377eb8', '#ff7f00', '#4daf4a',
                   '#f781bf', '#a65628', '#984ea3',
                   '#999999', '#e41a1c', '#dede00'])

# %%
clf = mixture.GaussianMixture(n_components=50, 
                              covariance_type='spherical',
                              max_iter=500)

# %%
clf.fit(moons_data)
# Out:
# GaussianMixture(covariance_type='spherical', init_params='kmeans',
#         max_iter=500, means_init=None, n_components=50, n_init=1,
#         precisions_init=None, random_state=None, reg_covar=1e-06,
#         tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#         weights_init=None)

# %%
mu = clf.means_
std = np.sqrt(clf.covariances_)

# %%
ax = plt.gca()
ax.cla()

ax.scatter(data[:, 0], data[:, 1], s=10, color=colors[(y>.5).numpy()])

for i in range(mu.shape[0]):
    ellipse = patches.Ellipse( (mu[i,0], mu[i,1]) , 3*std[i], 3*std[i], color='g', fill=False) 
    ax.add_artist(ellipse)

# %%
model = RobustModel(net, gmm, 0., dim=2, classes=2)

# %%
mu = torch.tensor(clf.means_ ,dtype=torch.float)
logvar = torch.tensor(np.log(clf.covariances_) ,dtype=torch.float)

gmm = models.GMM(50, 2, mu=mu, logvar=logvar)

# %%
model(data)
# Out:
# tensor([[-0.2904, -1.3783],
#         [-0.5485, -0.8623],
#         [-0.2205, -1.6199],
#         [-0.2953, -1.3639],
#         [-0.2653, -1.4566],
#         [-0.3449, -1.2319],
#         [-0.9526, -0.4874],
#         [-0.2519, -1.5019],
#         [-0.3460, -1.2293],
#         [-1.3357, -0.3051],
#         [-2.2187, -0.1151],
#         [-0.3278, -1.2747],
#         [-1.2312, -0.3452],
#         [-0.3892, -1.1319],
#         [-0.7454, -0.6435],
#         [-1.3978, -0.2839],
#         [-0.3123, -1.3159],
#         [-0.5280, -0.8911],
#         [-0.1517, -1.9605],
#         [-0.7706, -0.6213],
#         [-1.1387, -0.3860],
#         [-1.3061, -0.3159],
#         [-0.3823, -1.1465],
#         [-1.4994, -0.2527],
#         [-1.6912, -0.2037],
#         [-0.3101, -1.3220],
#         [-0.8427, -0.5631],
#         [-0.3368, -1.2520],
#         [-1.2275, -0.3468],
#         [-0.2045, -1.6879],
#         [-1.3422, -0.3028],
#         [-0.4044, -1.1007],
#         [-1.3513, -0.2996],
# ...

# %%
class RobustModel(nn.Module):
    def __init__(self, base_model, mixture_model, loglam, dim=784, classes=10):
        super().__init__()
        self.base_model = base_model
        
        self.dim = dim
        self.mm = mixture_model

        self.loglam = nn.Parameter(torch.tensor(loglam, dtype=torch.float))
        self.log_K = -torch.tensor(classes, dtype=torch.float).log()
        
        
    def forward(self, x):
        batch_size = x.shape[0]
        likelihood_per_peak = self.mm(x.view(batch_size, self.dim))
        like = torch.logsumexp(likelihood_per_peak, dim=0)

        x = self.base_model(x)
        
        a1 = torch.stack( (x + like[:,None], (self.loglam + self.log_K)*torch.ones_like(x) ), 0)
        b1 = torch.logsumexp(a1, 0).squeeze()

        a2 = torch.stack( (like , (self.loglam)*torch.ones_like(like) ), 0)
        b2 = torch.logsumexp(a2, 0).squeeze()[:,None]

        return b1-b2

# %%
y = model(data).max(1)[1]
( y == label ).float().mean()

colors = np.array(['#377eb8', '#ff7f00', '#4daf4a',
                   '#f781bf', '#a65628', '#984ea3',
                   '#999999', '#e41a1c', '#dede00'])

# %%
ax = plt.gca()
ax.cla()

ax.scatter(data[:, 0], data[:, 1], s=10, color=colors[(y>.5).numpy()])

for i in range(mu.shape[0]):
    ellipse = patches.Ellipse( (model.mm.mu[i,0], model.mm.mu[i,1]) , 3*std[i], 3*std[i], color='g', fill=False) 
    ax.add_artist(ellipse)

# %%
lr = 0.001
lr_gmm = 1e-6

param_groups = [{'params':model.mm.parameters(),'lr':lr_gmm, 'weight_decay':0.},
                {'params':model.base_model.parameters(),'lr':lr, 'weight_decay':5e-4}]

optimizer = optim.SGD(param_groups)

for _ in range(1000):
    train(data, label, net, optimizer)
