# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
from sklearn.metrics import roc_auc_score
from sklearn import mixture, preprocessing, datasets

from importlib import reload
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import patches

import torch.utils.data as data_utils

import utils.models as models
import utils.plotting as plotting
import utils.dataloaders as dl
import utils.traintest as tt
import utils.adversarial as adv
import utils.eval as ev
import model_params as params
import utils.resnet_orig as resnet
import utils.gmm_helpers as gmm_helpers

import model_paths

import utils.hybrid as hybrid

# %%
file = '../glow-pytorch-master/Checkpoints/glow_hybrid_dataset_CIFAR10.pth'
device = torch.device('cuda:7')

flow = hybrid.Glow(3, 8, 3)
model = hybrid.Hybrid(flow).to(device)

# %%
train_loader = dl.CIFAR10(train=True, augm_flag=False)

# %%
log_p = 0

for data, _ in train_loader:
    data = data.to(device)
    temp = model(data)[1].min().item()
    if temp < log_p:
        log_p = temp
print(log_p)

# %%
calibrated = CalibratedHybrid(model.cpu(), log_p)
# Out:
# (tensor([[-3.0897, -2.8278, -2.1787, -2.7098, -2.8538, -2.7689, -2.2523, -1.3220,
#           -2.3976, -2.0209],
#          [-1.9305, -2.6052, -2.3328, -2.6624, -2.4181, -3.1592, -2.6637, -1.7794,
#           -1.6869, -2.8276],
#          [-2.8734, -3.2104, -2.8854, -2.2080, -3.1973, -2.5225, -2.3373, -1.4154,
#           -2.5407, -1.6192],
#          [-2.0192, -2.1349, -2.1141, -2.7602, -2.0902, -2.1088, -3.1052, -2.8614,
#           -2.2279, -2.2058],
#          [-2.7629, -2.1950, -2.1470, -2.0494, -2.4890, -2.9700, -1.7881, -2.1031,
#           -2.4210, -2.6969],
#          [-2.5288, -2.6406, -3.2423, -2.6936, -3.3329, -3.4562, -1.6560, -1.6480,
#           -1.4821, -2.7413],
#          [-2.9491, -2.4900, -1.6158, -1.8361, -2.2594, -2.0746, -2.4808, -3.5609,
#           -3.1147, -2.1201],
#          [-2.3743, -1.8226, -2.0023, -2.7867, -3.0756, -1.8897, -2.7516, -1.6914,
#           -3.0249, -2.9051],
#          [-2.2210, -2.7211, -2.9165, -2.6472, -2.8894, -3.0162, -2.1557, -1.2644,
#           -1.8896, -3.0622],
#          [-2.5761, -2.4266, -2.8899, -1.9579, -2.1473, -1.6800, -3.2015, -4.2796,
#           -1.4624, -3.0066],
#          [-3.5713, -3.2889, -2.1706, -1.7981, -1.8406, -3.2221, -1.5338, -2.8008,
#           -2.5319, -2.2995],
#          [-2.0664, -3.9975, -3.1890, -1.8981, -2.4765, -2.6019, -1.3205, -2.5619,
#           -2.4678, -2.5660],
#          [-2.6005, -2.0150, -2.9286, -2.5039, -2.2842, -2.2739, -1.9467, -2.5447,
#           -2.0957, -2.2237],
#          [-2.4699, -2.7529, -2.3287, -2.5104, -2.2746, -1.9813, -2.2825, -2.3647,
#           -2.5517, -1.8430],
#          [-2.3365, -2.2576, -1.9486, -3.1751, -1.4014, -3.4413, -3.6787, -2.4549,
#           -1.7954, -2.8301],
#          [-2.6030, -2.0195, -2.6104, -3.0543, -2.0656, -1.6259, -2.9947, -2.8471,
#           -2.2238, -2.0187],
#          [-2.7015, -1.7534, -2.4856, -2.1115, -1.8393, -2.6165, -2.8705, -2.6371,
#           -2.3464, -2.3081],
#          [-1.8736, -2.5295, -1.9062, -3.0805, -2.3899, -1.6270, -2.9925, -3.3326,
#           -2.5431, -2.1243],
#          [-2.8470, -1.6306, -2.5075, -1.6857, -3.2609, -2.7307, -2.4614, -1.6159,
#           -3.9405, -2.6257],
#          [-2.5559, -2.2092, -2.2279, -2.6008, -2.3500, -1.6201, -2.3489, -2.7458,
#           -2.7804, -2.1567],
#          [-2.3726, -2.4928, -1.8586, -3.5401, -2.2910, -3.5899, -1.6996, -1.9311,
#           -2.1205, -2.7694],
#          [-3.3131, -3.5073, -3.3121, -1.9917, -1.1534, -1.4063, -3.2867, -4.1221,
#           -2.4305, -2.8385],
#          [-3.1083, -2.0428, -2.0623, -2.3666, -2.7717, -1.3574, -2.5677, -3.6295,
#           -2.9785, -2.0347],
#          [-2.3088, -2.8598, -1.8472, -3.9262, -2.7751, -2.1691, -2.7144, -2.5991,
#           -1.7284, -1.7651],
#          [-3.2622, -1.9471, -2.1316, -2.0516, -1.8943, -2.6372, -2.7669, -2.5743,
#           -2.1350, -2.3799],
#          [-2.4993, -1.8151, -1.9293, -2.8394, -2.7026, -2.5278, -1.7071, -2.2246,
#           -3.3190, -2.5413],
#          [-2.2076, -1.2897, -2.6176, -2.6743, -1.7400, -2.4302, -2.7058, -3.7982,
#           -2.4655, -3.3519],
#          [-2.8324, -3.3095, -1.9182, -1.3944, -2.7279, -3.1502, -1.8688, -2.3041,
#           -2.4164, -2.8446],
#          [-3.3696, -1.5078, -3.3162, -2.3740, -3.3048, -2.7564, -2.0508, -1.6199,
#           -2.7562, -2.0834],
#          [-2.5504, -2.7961, -2.8739, -2.3328, -2.4621, -3.3310, -1.9269, -1.2725,
#           -2.4982, -2.5457],
#          [-3.4391, -2.5799, -2.5882, -2.0485, -2.4966, -2.9056, -1.6001, -2.5110,
#           -2.0958, -1.9316]], device='cuda:7', grad_fn=<LogSoftmaxBackward>),
#  tensor([ -6760.2979,  -7660.0977,  -7764.1528,  -6735.5010,  -6600.1851,
#           -7325.5791,  -7706.9741,  -7448.9756,  -7422.7886,  -7779.8994,
#           -7845.6548,  -7713.3384,  -7279.2583,  -6419.1338,  -8389.5488,
#           -7205.2646,  -6911.2163,  -7509.7227,  -7740.9004,  -6907.4106,
#           -7530.3853,  -6884.0000,  -6932.2891,  -7166.1147,  -8310.3262,
#           -6801.5088,  -8421.5527,  -8619.8340,  -8741.1426,  -6994.9521,
#          -10032.3535,  -7088.2324,  -7242.6162,  -7880.7671,  -9484.5137,
#           -7918.8833,  -8212.5557,  -7749.8394,  -7563.7871,  -7018.6660,
#           -7701.2876,  -9388.7246,  -7958.2622,  -6942.0220,  -6940.0459,
#           -7135.6392,  -7798.6245,  -8039.1440,  -7542.0034,  -7827.2295,
#           -8117.9321,  -8351.6523,  -7941.9932,  -7890.2339,  -6599.3970,
#           -7096.4443,  -7391.1475,  -7095.6309,  -7513.6733,  -7301.7495,
#           -7433.3320,  -8407.8438,  -7331.1045,  -7053.0508,  -7197.1455,
#           -6783.9473,  -8075.1406,  -7440.3936,  -7050.0156,  -7482.9297,
#           -9227.1104,  -8151.0781,  -7498.7915,  -6948.8501,  -7076.9590,
#           -7355.3442,  -7436.8794,  -8004.3560,  -7270.8018,  -7450.8101],
#         device='cuda:7', grad_fn=<AddBackward0>))

# %%
calibrated.cpu()
torch.save(calibrated, 'SavedModels/other/' + 'hendrycks_CIFAR10' + '.pth')
